# %% [markdown]
# <a href="https://colab.research.google.com/github/divyavashist9758-eng/Student-performance-predictor/blob/main/p3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/employee_experience_vs_salary_200_rows.csv')

# %%
df
# Out:
#      Years_of_Experience   Salary
# 0                   1.53  17905.0
# 1                  15.60  85670.0
# 2                   8.77  65345.0
# 3                  14.47  83489.0
# 4                  19.56  86025.0
# ..                   ...      ...
# 195                10.04  75997.0
# 196                18.45  87947.0
# 197                 7.65  33444.0
# 198                13.00  69835.0
# 199                11.91  67265.0
#
# [200 rows x 2 columns]

# %%
df.shape
# Out:
# (200, 2)

# %%
x=df.iloc[:,0:1]

# %%
x

# %%
y=df.iloc[:,-1]

# %%
y

# %%
plt.scatter(df['Years_of_Experience'], df['Salary'])

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1,random_state=2)

# %%
from sklearn.preprocessing import StandardScaler

# %%
Scaler=StandardScaler()

# %%
x_train=Scaler.fit_transform(x_train)

# %%
x_test=Scaler.transform(x_test)

# %%
from sklearn.linear_model import LinearRegression

# %%
clf = LinearRegression()

# %%
clf=clf.fit(x_train,y_train)

# %%
y_pred=clf.predict(x_test)

# %%
y_test
# Out:
# 112     58879.0
# 29      42930.0
# 182     75796.0
# 199     67265.0
# 193     50677.0
# 85      46376.0
# 10      66957.0
# 54      44953.0
# 115    102084.0
# 35      77667.0
# 12      43103.0
# 92      26974.0
# 13      23122.0
# 126     48125.0
# 174     69993.0
# 2       65345.0
# 44      43663.0
# 3       83489.0
# 113     72673.0
# 14      38623.0
# Name: Salary, dtype: float64

# %%
y_pred
# Out:
# array([63008.16286042, 57966.43716553, 76418.46725974, 66712.28786074,
#        56800.3237395 , 61704.85961956, 72439.96262976, 54330.90707262,
#        90480.42327948, 83346.55290849, 51998.68022056, 28642.1142463 ,
#        30391.28438534, 62390.80869369, 71994.09573157, 55942.88739683,
#        57349.08299881, 75492.43600965, 67569.72420341, 45619.35383112])

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)
# Out:
# 0.793233161482697
