# %% [markdown]
# <a href="https://colab.research.google.com/github/divyavashist9758-eng/Student-performance-predictor/blob/main/placement.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/placement.csv')

# %%
df
# Out:
#     Unnamed: 0  cgpa     iq  placement
# 0            0   6.8  123.0          1
# 1            1   5.9  106.0          0
# 2            2   5.3  121.0          0
# 3            3   7.4  132.0          1
# 4            4   5.8  142.0          0
# ..         ...   ...    ...        ...
# 95          95   4.3  200.0          0
# 96          96   4.4   42.0          0
# 97          97   6.7  182.0          1
# 98          98   6.3  103.0          1
# 99          99   6.2  113.0          1
#
# [100 rows x 4 columns]

# %%
df.shape
# Out:
# (100, 4)

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
df.sample(7)
# Out:
#     Unnamed: 0  cgpa     iq  placement
# 59          59   4.8  112.0          0
# 10          10   6.0   45.0          1
# 40          40   4.9  134.0          0
# 13          13   6.4  116.0          1
# 61          61   7.3  137.0          1
# 56          56   6.1   65.0          0
# 64          64   7.0   64.0          1

# %%
df=df.iloc[:,1:]

# %%
df
# Out:
#     cgpa     iq  placement
# 0    6.8  123.0          1
# 1    5.9  106.0          0
# 2    5.3  121.0          0
# 3    7.4  132.0          1
# 4    5.8  142.0          0
# ..   ...    ...        ...
# 95   4.3  200.0          0
# 96   4.4   42.0          0
# 97   6.7  182.0          1
# 98   6.3  103.0          1
# 99   6.2  113.0          1
#
# [100 rows x 3 columns]

# %%
x=df.iloc[:,0:2]

# %%
x
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
y=df.iloc[:,-1]

# %%
y
# Out:
# 0     1
# 1     0
# 2     0
# 3     1
# 4     0
#      ..
# 95    0
# 96    0
# 97    1
# 98    1
# 99    1
# Name: placement, Length: 100, dtype: int64

# %%
plt.scatter(df['cgpa'],df['iq'],c=df['placement'])

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1,random_state=2)

# %%
x_train
# Out:
#     cgpa     iq
# 99   6.2  113.0
# 92   5.2  110.0
# 76   4.9  155.0
# 14   6.1  103.0
# 0    6.8  123.0
# ..   ...    ...
# 43   6.8  141.0
# 22   4.9  120.0
# 72   7.3  116.0
# 15   5.1  176.0
# 40   4.9  134.0
#
# [90 rows x 2 columns]

# %%
from sklearn.preprocessing import StandardScaler

# %%
Scaler=StandardScaler()

# %%
x_train=scaler.fit_transform(x_train)

# %%
x_test=scaler.transform(x_test)

# %%
x_train
# Out:
# array([[ 0.16981077, -0.27485148],
#        [-0.69853978, -0.35042165],
#        [-0.95904494,  0.7831308 ],
#        [ 0.08297572, -0.52675203],
#        [ 0.6908211 , -0.02295094],
#        [ 0.95132627,  0.68237059],
#        [ 1.21183143,  0.20375955],
#        [ 0.86449121, -0.30004154],
#        [ 1.12499638,  0.32970982],
#        [ 0.43031594, -0.85422273],
#        [ 0.6908211 , -0.85422273],
#        [ 0.77765616,  0.35489988],
#        [-0.2643645 ,  1.13579157],
#        [ 1.29866649, -1.58473431],
#        [-0.95904494, -1.58473431],
#        [ 0.95132627, -1.91220502],
#        [-0.87220989, -0.82903268],
#        [ 1.12499638, -1.86182491],
#        [ 0.60398605,  0.75794075],
#        [-0.00385934, -0.55194208],
#        [ 1.81967682,  1.0602214 ],
#        [-0.09069439, -0.45118186],
#        [-1.74056044, -0.60232219],
#        [ 0.51715099,  0.35489988],
#        [-0.2643645 ,  0.40527999],
#        [ 0.08297572, -1.08093322],
#        [-0.2643645 ,  0.48085015],
# ...

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression()

# %%
clf=clf.fit(x_train,y_train)

# %%
y_pred=clf.predict(x_test)

# %%
y_test
# Out:
# 83    1
# 30    1
# 56    0
# 24    0
# 16    0
# 23    0
# 2     0
# 27    1
# 28    0
# 13    1
# Name: placement, dtype: int64

# %%
y_pred
# Out:
# array([1, 1, 1, 0, 0, 0, 0, 1, 0, 1])

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x_train, y_train.values, clf=clf, legend=2)
# Out:
# <Axes: >
