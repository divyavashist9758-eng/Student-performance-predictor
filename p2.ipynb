# %% [markdown]
# <a href="https://colab.research.google.com/github/divyavashist9758-eng/Student-performance-predictor/blob/main/p2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/hours_vs_marks_200_rows.csv')

# %%
df
# Out:
#      Hours_Studied  Marks
# 0             4.37   49.8
# 1             9.56   78.5
# 2             7.59   68.8
# 3             6.39   59.8
# 4             2.40   47.6
# ..             ...    ...
# 195           4.14   46.5
# 196           7.53   65.5
# 197           9.07   74.7
# 198           8.98   75.8
# 199           8.02   74.5
#
# [200 rows x 2 columns]

# %%
df.shape
# Out:
# (200, 2)

# %%
x=df.iloc[:,0:1]

# %%
x
# Out:
#      Hours_Studied
# 0             4.37
# 1             9.56
# 2             7.59
# 3             6.39
# 4             2.40
# ..             ...
# 195           4.14
# 196           7.53
# 197           9.07
# 198           8.98
# 199           8.02
#
# [200 rows x 1 columns]

# %%
y=df.iloc[:,-1]

# %%
y
# Out:
# 0      49.8
# 1      78.5
# 2      68.8
# 3      59.8
# 4      47.6
#        ...
# 195    46.5
# 196    65.5
# 197    74.7
# 198    75.8
# 199    74.5
# Name: Marks, Length: 200, dtype: float64

# %%
df.shape
# Out:
# (200, 2)

# %%
plt.scatter(df['Hours_Studied'], df['Marks'])

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1,random_state=2)

# %%
from sklearn.preprocessing import StandardScaler

# %%
Scaler=StandardScaler()

# %%
x_train=Scaler.fit_transform(x_train)

# %%
x_test=Scaler.transform(x_test)

# %%
from sklearn.linear_model import LinearRegression

# %%
clf = LinearRegression()

# %%
clf=clf.fit(x_train,y_train)

# %%
y_pred=clf.predict(x_test)

# %%
y_test
# Out:
# 112    76.1
# 29     34.5
# 182    79.5
# 199    74.5
# 193    64.2
# 85     50.2
# 10     39.4
# 54     63.4
# 115    69.9
# 35     71.2
# 12     75.3
# 92     65.6
# 13     45.8
# 126    72.0
# 174    67.5
# 2      68.8
# 44     44.0
# 3      59.8
# 113    67.6
# 14     45.7
# Name: Marks, dtype: float64

# %%
y_pred
# Out:
# array([76.96779416, 37.37323702, 76.71877179, 70.24419012, 63.6699995 ,
#        49.87416009, 36.22773411, 62.07625632, 74.32815702, 71.53910645,
#        72.58500042, 69.39751406, 44.79410371, 71.93754225, 64.21784872,
#        68.10259772, 46.88589163, 62.12606079, 71.48930198, 43.4493829 ])

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)
# Out:
# 0.9612125653535744
